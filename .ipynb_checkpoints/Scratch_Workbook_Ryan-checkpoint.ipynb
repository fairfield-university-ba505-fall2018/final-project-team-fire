# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('CFDI.csv')
data.head()
# Out:
#    Incident Id Incident Status Incident Date  Incident Type Code  \
# 0          332               V    11/13/2014                 550
# 1         3753               V     5/22/2014                 550
# 2         4009               V    11/26/2014                 550
# 3         4160               V      6/4/2014                 550
# 4         4161               V      6/4/2014                 550
#
#       Incident Type Code Description Address on Wildland Mutual Aid Flag  \
# 0  Public service assistance, other.                   N               4
# 1  Public service assistance, other.                   N               N
# 2  Public service assistance, other.                   N               N
# 3  Public service assistance, other.                   N               N
# 4  Public service assistance, other.                   N               N
#
#                          Mutual Aid Flag Description       Alarm Date   \
# ...
